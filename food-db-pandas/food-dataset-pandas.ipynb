# %% [markdown]
# # Depuración dataset INCAP

# %%
import pandas as pd

# Configurar pandas para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# Leer el archivo CSV
df = pd.read_csv('./datasets/ALIMENTOS_INCAP_BRUTO.csv', delimiter=';')

#Listar columnas
print(df.columns)

# %%
import pandas as pd

# Configurar pandas para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# Leer el archivo CSV
df = pd.read_csv('./datasets/ALIMENTOS_INCAP_BRUTO.csv', delimiter=';')

df = df[~df['Combinada'].str.contains(r'\(GUATEMALA\)')]
df = df[~df['Combinada'].str.contains(r'\(HONDURAS\)')]
df = df[~df['Combinada'].str.contains(r'\(NICARAGUA\)')]
df = df[~df['Combinada'].str.contains(r'\(COSTA RICA\)')]
df = df[~df['Combinada'].str.contains(r'\(PANAMÁ\)')]
df = df[~df['Combinada'].str.contains(r'\(EL SALVADOR\)')]
df = df[~df['Combinada'].str.contains(r'\(GUATEMALA Y EL SALVADOR\)')]

# df = df.drop(columns=['Código', 'g\nCeniza'], axis=1)

df = df.drop(columns=['g\r\nCeniza'], axis=1)

df['Combinada'] = df['Combinada'].str.replace(',', '')

df.fillna(0, inplace=True)

df.rename(columns={
   'Combinada': 'name',
   'Agua\r\n%': 'waterPercentage',
   'Kcal.\r\nEnergía': 'caloriesKcal',
   'g\r\nProteina': 'proteinG',
   'g\r\nGrasa Total': 'totalFatG',
   'g\r\nCarbo-hidratos': 'carbohydratesG',
   'g\r\nFibra Diet.\r\ntotal': 'dietaryFiberG',
   'mg\r\nCalcio': 'calciumMg',
   'mg\r\nFosforo': 'phosphorusMg',
   'mg\r\nHierro': 'ironMg',
   'mg\r\nTiamina': 'thiamineMg',
   'mg\r\nRiboflavina': 'riboflavinMg',
   'mg\r\nNiacina': 'niacinMg',
   'mg\r\nVit. C': 'vitaminCmg',
   'mcg\r\nVit. A Equiv.\r\nRetinol': 'vitaminAEquivRetinolMcg',
   'g\r\nÁc. grasos\r\nmono-insat.': 'monounsaturatedFatG',
   'g\r\nÁc. grasos\r\npoli-insat.': 'polyunsaturatedFatG',
   'g\r\nÁc. Grasos\r\nsaturados': 'saturatedFatG',
   'mg\r\nColesterol': 'cholesterolMg',
   'mg\r\nPotasio': 'potassiumMg',
   'mg\r\nSodio': 'sodiumMg',
   'mg\r\nZinc': 'zincMg',
   'mg\r\nMagnesio': 'magnesiumMg',
   'mg\r\nVit. B6': 'vitaminB6Mg',
   'mcg\r\nVit. B12': 'vitaminB12Mcg',
   'mcg\r\nAc. Fólico': 'folicAcidMcg',
   'mcg\r\nFolato\r\nEquiv. FD': 'folateEquivFDMcg',
   '%\r\nFracción\r\nComestible': 'edibleFractionPercentage',
   'id_category': 'categoryId',
   }, inplace=True)

df['name'] = df['name'].str.title()

#Remove the last space charater for each row in the column

df['name'] = df['name'].str.rstrip()

display(df.head())
# Out:
#                              name  waterPercentage  caloriesKcal  proteinG  \
# 0               Arveja Grano Seco            11.27           341     24.55
# 1  Arveja Grano Seco Cocido S/Sal            69.49           118      8.34
# 2        Arveja Grano Seco Harina            10.00           351     23.40
# 3      Frijol Blanco Cocido S/Sal            63.08           139      9.73
# 4          Frijol Blanco Enlatado            70.10           117      7.26
#
#    totalFatG  carbohydratesG  dietaryFiberG  calciumMg  phosphorusMg  ironMg  \
# 0       1.16           60.37           25.5       55.0         366.0    4.43
# 1       0.39           21.10            8.3       14.0          99.0    1.29
# 2       2.10           62.00            0.0       81.0         297.0    6.00
# 3       0.35           25.09            6.3       90.0         113.0    3.70
# 4       0.29           21.94            4.8       73.0          91.0    2.99
#
# ...

# %%
df['categoryId'].groupby(df['categoryId'])

df['categoryId'].value_counts()
# Out:
# categoryId
# 3     181
# 4     161
# 13    120
# 5     110
# 11     97
# 12     88
# 9      82
# 6      70
# 10     39
# 1      34
# 2      33
# 7      33
# 8      27
# 14     25
# Name: count, dtype: int64

# %%
df.to_csv('./datasets/tabla-alimentos_procesada.csv', index=False)

df.to_json('./datasets/tabla-alimentos_procesada.json', orient='records', lines=True)

# %%
columns = df.columns.tolist()

for i in columns :
    print('private double ' + i + ';')
# Out:
# private double name;
# private double waterPercentage;
# private double caloriesKcal;
# private double proteinG;
# private double totalFatG;
# private double carbohydratesG;
# private double dietaryFiberG;
# private double calciumMg;
# private double phosphorusMg;
# private double ironMg;
# private double thiamineMg;
# private double riboflavinMg;
# private double niacinMg;
# private double vitaminCmg;
# private double vitaminAEquivRetinolMcg;
# private double monounsaturatedFatG;
# private double polyunsaturatedFatG;
# private double saturatedFatG;
# private double cholesterolMg;
# private double potassiumMg;
# private double sodiumMg;
# private double zincMg;
# private double magnesiumMg;
# private double vitaminB6Mg;
# private double vitaminB12Mcg;
# private double folicAcidMcg;
# private double folateEquivFDMcg;
# private double edibleFractionPercentage;
# private double categoryId;

# %%
columns = df.columns.tolist()

for i in columns :
    print('String ' + i + ';')
# Out:
# String name;
# String waterPercentage;
# String caloriesKcal;
# String proteinG;
# String totalFatG;
# String carbohydratesG;
# String dietaryFiberG;
# String calciumMg;
# String phosphorusMg;
# String ironMg;
# String thiamineMg;
# String riboflavinMg;
# String niacinMg;
# String vitaminCmg;
# String vitaminAEquivRetinolMcg;
# String monounsaturatedFatG;
# String polyunsaturatedFatG;
# String saturatedFatG;
# String cholesterolMg;
# String potassiumMg;
# String sodiumMg;
# String zincMg;
# String magnesiumMg;
# String vitaminB6Mg;
# String vitaminB12Mcg;
# String folicAcidMcg;
# String folateEquivFDMcg;
# String edibleFractionPercentage;
# String categoryId;

# %%
categories = [
      'Leguminosas, granos secos y derivados',
      'Nueces y semillas',
      'Verduras, hortalizas y otros vegetales',
      'Frutas y jugos de frutas',
      'Cereales, granos secos, harinas y pastas',
      'Galletas, panes, tortillas y similares',
      'Azúcares, mieles, dulces y golosinas',
      'Aceites y grasas',
      'Bebidas diversas',
      'Postres',
      'Comidas infantiles',
      'Aderezos, salsas y sopas',
      'Comidas preparadas: comerciales y caseras',
      'Condimentos'
   ]

df_categories = pd.DataFrame(categories, columns=['categoryName'])

df_categories['id'] = range(1, len(df_categories) + 1)

df_categories.head()
# Out:
#                                categoryName  id
# 0     Leguminosas, granos secos y derivados   1
# 1                         Nueces y semillas   2
# 2    Verduras, hortalizas y otros vegetales   3
# 3                  Frutas y jugos de frutas   4
# 4  Cereales, granos secos, harinas y pastas   5

# %%
# %pip install pymongo

# %%
from pymongo import MongoClient

client = MongoClient('mongodb+srv://admin-govegan:zMtj80lO2iuPb8IT@govegan-cluster.ixmcw2e.mongodb.net/')

db = client['ms-search-food']

# %%
from bson import ObjectId

categories_collection = db['foodCategories']

categories_cursor = categories_collection.find({})
category_id_map = {category['id']: category['_id'] for category in categories_cursor}

category_id_map
# Out:
# {1: ObjectId('665d490ef5d8544113c0f826'),
#  2: ObjectId('665d490ef5d8544113c0f827'),
#  3: ObjectId('665d490ef5d8544113c0f828'),
#  4: ObjectId('665d490ef5d8544113c0f829'),
#  5: ObjectId('665d490ef5d8544113c0f82a'),
#  6: ObjectId('665d490ef5d8544113c0f82b'),
#  7: ObjectId('665d490ef5d8544113c0f82c'),
#  8: ObjectId('665d490ef5d8544113c0f82d'),
#  9: ObjectId('665d490ef5d8544113c0f82e'),
#  10: ObjectId('665d490ef5d8544113c0f82f'),
#  11: ObjectId('665d490ef5d8544113c0f830'),
#  12: ObjectId('665d490ef5d8544113c0f831'),
#  13: ObjectId('665d490ef5d8544113c0f832'),
#  14: ObjectId('665d490ef5d8544113c0f833')}

# %%
foods_collection = db['foods']

df['category_Id'] = df['categoryId'].map(category_id_map)

nan_rows = df[df['categoryId'].isna()]
if not nan_rows.empty:
    print("Filas con categoryId NaN:")
    print(nan_rows)
    # Opcional: Omitir filas con NaN en categoryId
    df = df.dropna(subset=['categoryId'])
else:
    print("No hay filas con categoryId NaN")
# Out:
# No hay filas con categoryId NaN

# %%
for index, row in df.iterrows():
    food = row.to_dict()
    food['_id'] = ObjectId()
    foods_collection.insert_one(food)
